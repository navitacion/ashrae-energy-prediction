# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
from catboost import CatBoostRegressor, Pool
import random
import gc
import os
import datetime
import pickle
import optuna
import sqlite3

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_squared_error

myfavouritenumber = 0
seed = myfavouritenumber
random.seed(seed)

pd.set_option('max_rows', 9999)
pd.set_option('max_columns', 9999)

# %% [markdown]
# Half_Half_LightGBM Training

# %%
class Trainer:
    def __init__(self, importance_df, model_type='lgb', use_feature_num=None):
        self.model_type = model_type
        
        if use_feature_num is not None:
            self.features = importance_df['feature'][:use_feature_num].tolist()
        else:
            self.features = None
            
    def train_half_optuna(self, X_train, y_train, params, num_boost_round, early_stopping_rounds, verbose=200, trial=None):
        
        if self.features is None:
            self.features = X_train.columns
            
        self.features = [c for c in self.features if c not in ['M']]
            
        self.X_train = X_train[self.features]
        self.y_train = y_train
        pruning_callback = optuna.integration.LightGBMPruningCallback(trial, 'rmse')
        
        if self.model_type == 'lgb':
            d_half_1 = lgb.Dataset(self.X_train[:int(self.X_train.shape[0] / 2)], 
                                   label=self.y_train[:int(X_train.shape[0] / 2)])
            d_half_2 = lgb.Dataset(self.X_train[int(self.X_train.shape[0] / 2):], 
                                   label=self.y_train[int(X_train.shape[0] / 2):])

            self.model_1 = lgb.train(params, train_set=d_half_1, num_boost_round=num_boost_round, 
                                     valid_sets=[d_half_2], verbose_eval=verbose, 
                                     early_stopping_rounds=early_stopping_rounds, 
                                     callbacks=[pruning_callback])
            
            oof = self.model_1.predict(self.X_train[int(self.X_train.shape[0] / 2):],
                                       num_iteration=self.model_1.best_iteration)
            oof = np.clip(oof, 0, a_max=None)
            
            rmse = np.sqrt(mean_squared_error(self.y_train[int(X_train.shape[0] / 2):], oof))
            
        return rmse

# %%
# config
train_pkl_path = '../input/prep_train_20191118.pkl'
test_pkl_path = '../input/prep_test_20191118.pkl'
importance_path = '../Importance/importance_20191118.csv'
model_type = 'lgb'

# Create SQLite Table
con = sqlite3.connect('ashrae_lgb.db')

def objective(trial):
    # Search Parameter Range
    set_lgb_params = {
        'objective': 'regression',
        'boosting_type': 'gbrt',
        'metric': 'rmse',
        'n_jobs': -1,
        'learning_rate': 0.01,
        'max_bin': 255,
        'max_depth': trial.suggest_int('max_depth', 6, 10),
        'num_leaves': trial.suggest_int('num_leaves', 100, 300),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 0.9),
        'subsample': trial.suggest_uniform('subsample', 0.6, 0.9),
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 10, 50),
        'feature_fraction': trial.suggest_uniform('feature_fraction', 0.3, 0.9),
        'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.3, 0.9),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 20),
        'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-2, 1e+3),
        'verbose': -1,
        'seed': 42
    }
    
    num_boost_round = 1000
    early_stopping_rounds = 50
    num_feature = 30
    verbose = False
    
    # Train Model
    trainer = Trainer(importance_df=importance_df, model_type=model_type, use_feature_num=num_feature)
    rmse = trainer.train_half_optuna(train[0], train[1], set_lgb_params, num_boost_round, 
                                       early_stopping_rounds, verbose, trial)

    return rmse

# %%
# Training
# Data Loading
with open(train_pkl_path, 'rb') as f:
    train = pickle.load(f)

importance_df = pd.read_csv(importance_path)

pruner = optuna.pruners.SuccessiveHalvingPruner(min_resource=50)

# New Study
# study = optuna.create_study(
#     study_name='ashrae_lgb',
#     storage='sqlite:///ashrae_lgb.db',
#     load_if_exists=True,
#     direction='minimize',
#     pruner=pruner
# )

# Reload Intermediate state
study = optuna.load_study(
    study_name='ashrae_lgb',
    storage='sqlite:///ashrae_lgb.db',
    pruner=pruner
)

study.optimize(objective, timeout=60*60*30)
# Out:
# [I 2019-11-23 08:38:26,751] Setting status of trial#132 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 08:57:05,598] Finished trial#133 resulted in value: 1.1386632947842301. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 08:59:38,894] Setting status of trial#134 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 09:00:33,125] Setting status of trial#135 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 09:18:40,141] Finished trial#136 resulted in value: 1.140466381979324. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 09:19:30,734] Setting status of trial#137 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 09:20:22,202] Setting status of trial#138 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 09:29:31,386] Setting status of trial#139 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-23 09:30:21,965] Setting status of trial#140 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 09:31:12,308] Setting status of trial#141 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 09:48:24,446] Finished trial#142 resulted in value: 1.1403411342431782. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 10:07:19,246] Finished trial#143 resulted in value: 1.1411014741872125. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 10:24:40,134] Finished trial#144 resulted in value: 1.141594926243644. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 10:43:26,116] Finished trial#145 resulted in value: 1.1401310903438677. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 11:00:49,345] Finished trial#146 resulted in value: 1.1396889960570589. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 11:18:20,218] Finished trial#147 resulted in value: 1.140948136525221. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 11:20:45,347] Setting status of trial#148 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 11:21:36,127] Setting status of trial#149 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 11:22:24,325] Setting status of trial#150 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 11:40:53,246] Finished trial#151 resulted in value: 1.1391772573465704. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 11:58:23,094] Finished trial#152 resulted in value: 1.138440248492171. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 11:59:12,565] Setting status of trial#153 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 12:18:04,958] Finished trial#154 resulted in value: 1.1381525162176713. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 12:35:46,496] Finished trial#155 resulted in value: 1.1391137086409266. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 12:38:30,703] Setting status of trial#156 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 12:39:20,977] Setting status of trial#157 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 12:57:14,946] Finished trial#158 resulted in value: 1.1409549553934402. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 13:15:41,125] Finished trial#159 resulted in value: 1.1396303147712479. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 13:16:31,003] Setting status of trial#160 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 13:17:23,173] Setting status of trial#161 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 13:18:10,957] Setting status of trial#162 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 13:21:01,943] Setting status of trial#163 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 13:23:47,166] Setting status of trial#164 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 13:31:56,253] Setting status of trial#165 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-23 13:32:46,759] Setting status of trial#166 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 13:35:25,548] Setting status of trial#167 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 13:52:35,058] Finished trial#168 resulted in value: 1.1396821146632943. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 13:53:18,790] Setting status of trial#169 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 14:10:28,217] Finished trial#170 resulted in value: 1.1411210417604087. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 14:11:20,843] Setting status of trial#171 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 14:29:08,199] Finished trial#172 resulted in value: 1.1393102975477487. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 14:47:10,690] Finished trial#173 resulted in value: 1.1395608794632164. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 14:48:03,554] Setting status of trial#174 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 14:52:02,937] Setting status of trial#175 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 14:52:55,917] Setting status of trial#176 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 14:55:44,564] Setting status of trial#177 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 15:11:21,244] Finished trial#178 resulted in value: 1.1416115480624065. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 15:14:00,652] Setting status of trial#179 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 15:14:56,150] Setting status of trial#180 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 15:24:13,737] Setting status of trial#181 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-23 15:26:42,659] Setting status of trial#182 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 15:44:19,778] Finished trial#183 resulted in value: 1.1403773679162996. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 16:01:58,255] Finished trial#184 resulted in value: 1.139843408863006. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 16:04:30,529] Setting status of trial#185 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 16:05:23,560] Setting status of trial#186 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 16:24:03,759] Finished trial#187 resulted in value: 1.1392376698778275. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 16:26:33,925] Setting status of trial#188 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 16:29:12,315] Setting status of trial#189 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 16:31:45,989] Setting status of trial#190 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 16:32:37,916] Setting status of trial#191 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 16:50:29,543] Finished trial#192 resulted in value: 1.13956132759886. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 16:53:18,274] Setting status of trial#193 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 17:12:05,695] Finished trial#194 resulted in value: 1.1404532442070137. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 17:14:35,625] Setting status of trial#195 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 17:15:28,519] Setting status of trial#196 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 17:25:22,800] Setting status of trial#197 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-23 17:34:37,877] Setting status of trial#198 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-23 17:37:24,515] Setting status of trial#199 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 17:46:34,366] Setting status of trial#200 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-23 17:47:22,929] Setting status of trial#201 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 17:48:15,862] Setting status of trial#202 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 17:49:04,741] Setting status of trial#203 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 17:58:57,801] Setting status of trial#204 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-23 18:16:54,499] Finished trial#205 resulted in value: 1.139448530708883. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 18:26:34,625] Setting status of trial#206 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-23 18:27:24,653] Setting status of trial#207 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 18:28:12,811] Setting status of trial#208 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 18:29:05,344] Setting status of trial#209 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 18:48:17,566] Finished trial#210 resulted in value: 1.1400850698452425. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 18:49:05,893] Setting status of trial#211 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 18:58:55,590] Setting status of trial#212 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-23 18:59:48,789] Setting status of trial#213 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 19:00:36,702] Setting status of trial#214 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 19:20:02,389] Finished trial#215 resulted in value: 1.139130884263791. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 19:22:46,668] Setting status of trial#216 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 19:32:43,834] Setting status of trial#217 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-23 19:41:20,015] Setting status of trial#218 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-23 19:42:15,695] Setting status of trial#219 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 20:00:00,950] Finished trial#220 resulted in value: 1.1399776761966427. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 20:08:26,375] Setting status of trial#221 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-23 20:09:17,350] Setting status of trial#222 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 20:19:01,011] Setting status of trial#223 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-23 20:19:52,835] Setting status of trial#224 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 20:20:42,947] Setting status of trial#225 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 20:23:19,006] Setting status of trial#226 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 20:26:07,207] Setting status of trial#227 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 20:26:59,520] Setting status of trial#228 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 20:36:56,437] Setting status of trial#229 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-23 20:37:50,263] Setting status of trial#230 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 20:40:40,676] Setting status of trial#231 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 20:41:28,411] Setting status of trial#232 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 20:42:20,892] Setting status of trial#233 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 20:43:10,109] Setting status of trial#234 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 20:44:01,958] Setting status of trial#235 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 20:44:50,093] Setting status of trial#236 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 20:45:43,020] Setting status of trial#237 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 20:46:34,682] Setting status of trial#238 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 20:56:15,969] Setting status of trial#239 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-23 20:57:05,159] Setting status of trial#240 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 21:05:48,427] Setting status of trial#241 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-23 21:06:41,962] Setting status of trial#242 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 21:07:34,495] Setting status of trial#243 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 21:25:40,463] Finished trial#244 resulted in value: 1.138468466152568. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 21:43:43,739] Finished trial#245 resulted in value: 1.138660492702818. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 21:44:37,957] Setting status of trial#246 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 21:47:34,925] Setting status of trial#247 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 21:48:25,209] Setting status of trial#248 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 21:49:19,268] Setting status of trial#249 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 21:52:08,447] Setting status of trial#250 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 22:10:44,551] Finished trial#251 resulted in value: 1.1400973422003418. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 22:13:34,170] Setting status of trial#252 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 22:14:26,228] Setting status of trial#253 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 22:17:23,163] Setting status of trial#254 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 22:18:17,204] Setting status of trial#255 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 22:19:11,541] Setting status of trial#256 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 22:22:01,744] Setting status of trial#257 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 22:31:06,025] Setting status of trial#258 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-23 22:31:57,458] Setting status of trial#259 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 22:32:52,843] Setting status of trial#260 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 22:35:35,862] Setting status of trial#261 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 22:36:25,853] Setting status of trial#262 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 22:54:58,053] Finished trial#263 resulted in value: 1.1401027377414321. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 23:04:30,169] Setting status of trial#264 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-23 23:07:03,030] Setting status of trial#265 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 23:07:50,609] Setting status of trial#266 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 23:16:22,163] Setting status of trial#267 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-23 23:17:13,339] Setting status of trial#268 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 23:20:05,455] Setting status of trial#269 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 23:38:53,473] Finished trial#270 resulted in value: 1.1400374884367568. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-23 23:41:43,702] Setting status of trial#271 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-23 23:42:33,377] Setting status of trial#272 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-23 23:43:26,709] Setting status of trial#273 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 00:02:36,776] Finished trial#274 resulted in value: 1.1405015076159595. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-24 00:11:43,348] Setting status of trial#275 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-24 00:12:38,082] Setting status of trial#276 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 00:15:31,049] Setting status of trial#277 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 00:18:21,223] Setting status of trial#278 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 00:19:14,463] Setting status of trial#279 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 00:21:41,848] Setting status of trial#280 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 00:22:35,858] Setting status of trial#281 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 00:23:33,919] Setting status of trial#282 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 00:26:16,070] Setting status of trial#283 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 00:27:11,039] Setting status of trial#284 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 00:30:40,127] Setting status of trial#285 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 00:31:33,496] Setting status of trial#286 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 00:32:25,579] Setting status of trial#287 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 00:33:13,242] Setting status of trial#288 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 00:33:56,935] Setting status of trial#289 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 00:36:43,406] Setting status of trial#290 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 00:37:35,541] Setting status of trial#291 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 00:38:13,912] Setting status of trial#292 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 00:40:46,780] Setting status of trial#293 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 00:41:29,427] Setting status of trial#294 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 00:42:21,678] Setting status of trial#295 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 00:52:21,544] Setting status of trial#296 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-24 01:10:41,231] Finished trial#297 resulted in value: 1.14022495292233. Current best value is 1.1378703133301726 with parameters: {'bagging_fraction': 0.42797307400289963, 'bagging_freq': 6, 'colsample_bytree': 0.8659940184256816, 'feature_fraction': 0.852216419174993, 'max_depth': 10, 'min_data_in_leaf': 47, 'num_leaves': 242, 'reg_lambda': 137.8767751523373, 'subsample': 0.8922113062563624}.
# [I 2019-11-24 01:11:30,523] Setting status of trial#298 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 01:21:48,830] Setting status of trial#299 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-24 01:41:38,977] Finished trial#300 resulted in value: 1.1378522421159347. Current best value is 1.1378522421159347 with parameters: {'bagging_fraction': 0.42523401307460185, 'bagging_freq': 6, 'colsample_bytree': 0.7187743617504782, 'feature_fraction': 0.8822412268247286, 'max_depth': 10, 'min_data_in_leaf': 42, 'num_leaves': 279, 'reg_lambda': 114.8060332041216, 'subsample': 0.8631504025541011}.
# [I 2019-11-24 01:42:28,786] Setting status of trial#301 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 01:43:24,734] Setting status of trial#302 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 01:44:23,268] Setting status of trial#303 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 01:54:30,593] Setting status of trial#304 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-24 01:55:20,384] Setting status of trial#305 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 01:56:14,220] Setting status of trial#306 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 01:57:05,008] Setting status of trial#307 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 02:06:00,912] Setting status of trial#308 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-24 02:06:55,373] Setting status of trial#309 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 02:07:48,217] Setting status of trial#310 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 02:10:41,858] Setting status of trial#311 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 02:11:36,682] Setting status of trial#312 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 02:14:36,344] Setting status of trial#313 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 02:15:28,592] Setting status of trial#314 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 02:16:17,252] Setting status of trial#315 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 02:19:03,925] Setting status of trial#316 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 02:22:13,677] Setting status of trial#317 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 02:23:08,606] Setting status of trial#318 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 02:42:33,448] Finished trial#319 resulted in value: 1.1385570018857123. Current best value is 1.1378522421159347 with parameters: {'bagging_fraction': 0.42523401307460185, 'bagging_freq': 6, 'colsample_bytree': 0.7187743617504782, 'feature_fraction': 0.8822412268247286, 'max_depth': 10, 'min_data_in_leaf': 42, 'num_leaves': 279, 'reg_lambda': 114.8060332041216, 'subsample': 0.8631504025541011}.
# [I 2019-11-24 02:43:26,214] Setting status of trial#320 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 02:44:15,036] Setting status of trial#321 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 02:45:08,572] Setting status of trial#322 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 02:46:02,688] Setting status of trial#323 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 02:48:30,767] Setting status of trial#324 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 02:57:48,076] Setting status of trial#325 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-24 03:00:47,984] Setting status of trial#326 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 03:19:53,754] Finished trial#327 resulted in value: 1.139339272544123. Current best value is 1.1378522421159347 with parameters: {'bagging_fraction': 0.42523401307460185, 'bagging_freq': 6, 'colsample_bytree': 0.7187743617504782, 'feature_fraction': 0.8822412268247286, 'max_depth': 10, 'min_data_in_leaf': 42, 'num_leaves': 279, 'reg_lambda': 114.8060332041216, 'subsample': 0.8631504025541011}.
# [I 2019-11-24 03:38:46,157] Finished trial#328 resulted in value: 1.138590443108138. Current best value is 1.1378522421159347 with parameters: {'bagging_fraction': 0.42523401307460185, 'bagging_freq': 6, 'colsample_bytree': 0.7187743617504782, 'feature_fraction': 0.8822412268247286, 'max_depth': 10, 'min_data_in_leaf': 42, 'num_leaves': 279, 'reg_lambda': 114.8060332041216, 'subsample': 0.8631504025541011}.
# [I 2019-11-24 03:41:24,387] Setting status of trial#329 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 03:42:18,460] Setting status of trial#330 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 03:45:13,316] Setting status of trial#331 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 03:55:01,075] Setting status of trial#332 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-24 03:55:41,619] Setting status of trial#333 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 04:04:39,886] Setting status of trial#334 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-24 04:05:32,223] Setting status of trial#335 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 04:15:05,133] Setting status of trial#336 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-24 04:17:49,875] Setting status of trial#337 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 04:18:40,491] Setting status of trial#338 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 04:19:34,151] Setting status of trial#339 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 04:28:54,046] Setting status of trial#340 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-24 04:29:48,641] Setting status of trial#341 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 04:30:42,864] Setting status of trial#342 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 04:39:25,807] Setting status of trial#343 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-24 04:40:18,670] Setting status of trial#344 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 04:43:19,905] Setting status of trial#345 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 04:44:09,699] Setting status of trial#346 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 04:46:58,128] Setting status of trial#347 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 04:47:49,105] Setting status of trial#348 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 04:48:41,962] Setting status of trial#349 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 04:51:35,964] Setting status of trial#350 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 04:52:26,282] Setting status of trial#351 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 04:53:17,347] Setting status of trial#352 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 05:03:07,142] Setting status of trial#353 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-24 05:06:00,004] Setting status of trial#354 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 05:06:50,425] Setting status of trial#355 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 05:07:41,852] Setting status of trial#356 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 05:10:33,435] Setting status of trial#357 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 05:11:20,617] Setting status of trial#358 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 05:12:13,884] Setting status of trial#359 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 05:13:08,102] Setting status of trial#360 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 05:14:00,948] Setting status of trial#361 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 05:16:37,481] Setting status of trial#362 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 05:17:32,917] Setting status of trial#363 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 05:26:13,619] Setting status of trial#364 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-24 05:29:03,958] Setting status of trial#365 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 05:29:55,885] Setting status of trial#366 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 05:30:46,052] Setting status of trial#367 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 05:31:29,304] Setting status of trial#368 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 05:32:21,324] Setting status of trial#369 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 05:35:15,799] Setting status of trial#370 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 05:36:06,667] Setting status of trial#371 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 05:38:39,801] Setting status of trial#372 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 05:39:34,558] Setting status of trial#373 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 05:40:24,855] Setting status of trial#374 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 05:41:18,711] Setting status of trial#375 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 05:43:58,347] Setting status of trial#376 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 05:44:52,485] Setting status of trial#377 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 05:47:40,726] Setting status of trial#378 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 05:50:29,129] Setting status of trial#379 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 05:51:24,667] Setting status of trial#380 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 05:54:12,686] Setting status of trial#381 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 05:55:07,530] Setting status of trial#382 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 05:55:55,144] Setting status of trial#383 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 05:56:49,613] Setting status of trial#384 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 05:57:41,056] Setting status of trial#385 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 05:58:36,050] Setting status of trial#386 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 05:59:26,365] Setting status of trial#387 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 06:00:20,273] Setting status of trial#388 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 06:01:12,902] Setting status of trial#389 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 06:02:03,839] Setting status of trial#390 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 06:10:41,236] Setting status of trial#391 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-24 06:11:37,353] Setting status of trial#392 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 06:12:33,292] Setting status of trial#393 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 06:13:28,362] Setting status of trial#394 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 06:14:23,780] Setting status of trial#395 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 06:15:15,912] Setting status of trial#396 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 06:16:08,276] Setting status of trial#397 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 06:19:01,973] Setting status of trial#398 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 06:21:44,758] Setting status of trial#399 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 06:22:37,915] Setting status of trial#400 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 06:23:27,388] Setting status of trial#401 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 06:26:07,785] Setting status of trial#402 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 06:26:59,203] Setting status of trial#403 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 06:30:53,807] Setting status of trial#404 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 06:31:46,618] Setting status of trial#405 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 06:32:41,506] Setting status of trial#406 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 06:33:34,510] Setting status of trial#407 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 06:34:26,664] Setting status of trial#408 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 06:35:20,586] Setting status of trial#409 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 06:36:12,630] Setting status of trial#410 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 06:37:03,053] Setting status of trial#411 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 06:37:51,808] Setting status of trial#412 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 06:40:45,567] Setting status of trial#413 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 06:41:36,523] Setting status of trial#414 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 06:42:30,448] Setting status of trial#415 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 06:52:11,454] Setting status of trial#416 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-24 06:52:55,715] Setting status of trial#417 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 06:53:48,708] Setting status of trial#418 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 06:54:39,025] Setting status of trial#419 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 06:55:30,027] Setting status of trial#420 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 06:56:28,361] Setting status of trial#421 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 06:57:18,485] Setting status of trial#422 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 06:58:12,116] Setting status of trial#423 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 07:07:33,436] Setting status of trial#424 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-24 07:08:26,879] Setting status of trial#425 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 07:11:23,462] Setting status of trial#426 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 07:12:16,950] Setting status of trial#427 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 07:22:11,184] Setting status of trial#428 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-24 07:23:06,437] Setting status of trial#429 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 07:23:58,416] Setting status of trial#430 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 07:24:44,458] Setting status of trial#431 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 07:25:35,507] Setting status of trial#432 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 07:28:12,543] Setting status of trial#433 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 07:29:06,341] Setting status of trial#434 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 07:30:00,475] Setting status of trial#435 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 07:32:32,819] Setting status of trial#436 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 07:42:30,604] Setting status of trial#437 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-24 07:43:21,178] Setting status of trial#438 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 07:44:12,947] Setting status of trial#439 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 07:45:08,797] Setting status of trial#440 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 07:45:59,460] Setting status of trial#441 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 07:48:46,204] Setting status of trial#442 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 07:49:37,744] Setting status of trial#443 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 07:52:13,574] Setting status of trial#444 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 07:53:03,578] Setting status of trial#445 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 07:53:50,148] Setting status of trial#446 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 07:54:47,608] Setting status of trial#447 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 07:55:42,128] Setting status of trial#448 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 07:56:35,065] Setting status of trial#449 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 07:57:36,465] Setting status of trial#450 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 08:16:47,130] Finished trial#451 resulted in value: 1.140406834671472. Current best value is 1.1378522421159347 with parameters: {'bagging_fraction': 0.42523401307460185, 'bagging_freq': 6, 'colsample_bytree': 0.7187743617504782, 'feature_fraction': 0.8822412268247286, 'max_depth': 10, 'min_data_in_leaf': 42, 'num_leaves': 279, 'reg_lambda': 114.8060332041216, 'subsample': 0.8631504025541011}.
# ...
# [I 2019-11-24 08:50:22,356] Setting status of trial#455 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 09:00:49,256] Setting status of trial#456 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-24 09:03:37,559] Setting status of trial#457 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 09:06:24,858] Setting status of trial#458 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 09:26:01,812] Finished trial#459 resulted in value: 1.1399541470220431. Current best value is 1.1378522421159347 with parameters: {'bagging_fraction': 0.42523401307460185, 'bagging_freq': 6, 'colsample_bytree': 0.7187743617504782, 'feature_fraction': 0.8822412268247286, 'max_depth': 10, 'min_data_in_leaf': 42, 'num_leaves': 279, 'reg_lambda': 114.8060332041216, 'subsample': 0.8631504025541011}.
# [I 2019-11-24 09:26:56,064] Setting status of trial#460 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 09:29:55,853] Setting status of trial#461 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 09:30:51,227] Setting status of trial#462 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 09:40:22,711] Setting status of trial#463 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-24 09:41:18,584] Setting status of trial#464 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 09:43:53,020] Setting status of trial#465 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 09:44:47,829] Setting status of trial#466 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 09:45:42,895] Setting status of trial#467 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 09:48:40,491] Setting status of trial#468 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 09:51:31,834] Setting status of trial#469 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 09:52:23,227] Setting status of trial#470 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 09:53:16,765] Setting status of trial#471 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 09:54:13,580] Setting status of trial#472 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 09:57:08,042] Setting status of trial#473 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 09:57:55,879] Setting status of trial#474 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 10:00:50,831] Setting status of trial#475 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 10:01:44,379] Setting status of trial#476 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 10:02:36,398] Setting status of trial#477 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 10:03:33,684] Setting status of trial#478 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 10:04:28,901] Setting status of trial#479 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 10:05:23,166] Setting status of trial#480 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 10:08:13,069] Setting status of trial#481 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 10:09:08,247] Setting status of trial#482 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 10:09:59,176] Setting status of trial#483 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 10:10:52,468] Setting status of trial#484 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 10:13:52,443] Setting status of trial#485 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 10:14:44,985] Setting status of trial#486 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 10:15:38,489] Setting status of trial#487 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 10:18:28,499] Setting status of trial#488 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 10:19:22,698] Setting status of trial#489 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 10:22:26,344] Setting status of trial#490 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 10:23:19,957] Setting status of trial#491 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 10:24:13,363] Setting status of trial#492 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 10:25:08,916] Setting status of trial#493 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 10:26:04,192] Setting status of trial#494 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 10:26:54,592] Setting status of trial#495 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 10:29:35,444] Setting status of trial#496 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 10:30:31,044] Setting status of trial#497 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 10:31:10,917] Setting status of trial#498 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 10:40:50,333] Setting status of trial#499 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-24 10:41:45,456] Setting status of trial#500 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 10:51:01,177] Setting status of trial#501 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-24 10:51:51,656] Setting status of trial#502 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 10:52:45,337] Setting status of trial#503 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 10:53:37,317] Setting status of trial#504 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 10:54:33,417] Setting status of trial#505 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 10:55:27,851] Setting status of trial#506 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 10:58:23,892] Setting status of trial#507 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 10:59:18,042] Setting status of trial#508 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 11:00:12,465] Setting status of trial#509 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 11:01:06,220] Setting status of trial#510 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 11:03:50,420] Setting status of trial#511 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 11:06:42,914] Setting status of trial#512 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 11:07:34,707] Setting status of trial#513 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 11:08:31,876] Setting status of trial#514 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 11:09:26,923] Setting status of trial#515 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 11:10:21,546] Setting status of trial#516 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 11:13:03,062] Setting status of trial#517 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 11:15:59,347] Setting status of trial#518 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 11:16:51,883] Setting status of trial#519 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 11:17:42,414] Setting status of trial#520 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 11:18:35,016] Setting status of trial#521 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 11:21:23,007] Setting status of trial#522 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 11:24:05,283] Setting status of trial#523 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 11:26:44,947] Setting status of trial#524 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 11:27:51,915] Setting status of trial#525 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 11:28:45,233] Setting status of trial#526 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 11:29:40,271] Setting status of trial#527 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 11:30:33,980] Setting status of trial#528 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 11:31:25,133] Setting status of trial#529 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 11:32:20,290] Setting status of trial#530 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 11:42:12,117] Setting status of trial#531 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-24 11:44:59,000] Setting status of trial#532 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 11:45:54,458] Setting status of trial#533 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 11:46:47,590] Setting status of trial#534 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 11:47:42,740] Setting status of trial#535 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 11:48:36,317] Setting status of trial#536 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 11:58:25,519] Setting status of trial#537 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-24 12:01:02,096] Setting status of trial#538 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 12:01:54,268] Setting status of trial#539 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 12:15:37,350] Setting status of trial#540 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-24 12:16:29,816] Setting status of trial#541 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 12:17:25,223] Setting status of trial#542 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 12:18:19,904] Setting status of trial#543 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 12:19:13,257] Setting status of trial#544 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 12:20:06,853] Setting status of trial#545 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 12:21:01,719] Setting status of trial#546 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 12:21:56,221] Setting status of trial#547 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 12:22:50,105] Setting status of trial#548 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 12:41:24,991] Finished trial#549 resulted in value: 1.1408421787335317. Current best value is 1.1378522421159347 with parameters: {'bagging_fraction': 0.42523401307460185, 'bagging_freq': 6, 'colsample_bytree': 0.7187743617504782, 'feature_fraction': 0.8822412268247286, 'max_depth': 10, 'min_data_in_leaf': 42, 'num_leaves': 279, 'reg_lambda': 114.8060332041216, 'subsample': 0.8631504025541011}.
# [I 2019-11-24 12:42:10,198] Setting status of trial#550 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 12:43:03,909] Setting status of trial#551 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 12:43:57,812] Setting status of trial#552 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 12:44:54,304] Setting status of trial#553 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 12:47:41,871] Setting status of trial#554 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 12:48:35,723] Setting status of trial#555 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 12:49:28,841] Setting status of trial#556 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 12:50:22,361] Setting status of trial#557 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 12:53:19,292] Setting status of trial#558 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 12:54:09,095] Setting status of trial#559 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 12:55:05,594] Setting status of trial#560 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 13:04:55,438] Setting status of trial#561 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-24 13:05:43,767] Setting status of trial#562 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 13:06:29,335] Setting status of trial#563 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 13:07:24,286] Setting status of trial#564 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 13:17:14,532] Setting status of trial#565 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-24 13:18:03,196] Setting status of trial#566 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 13:18:56,705] Setting status of trial#567 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 13:19:41,090] Setting status of trial#568 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 13:22:37,483] Setting status of trial#569 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 13:41:43,608] Finished trial#570 resulted in value: 1.1390854606862229. Current best value is 1.1378522421159347 with parameters: {'bagging_fraction': 0.42523401307460185, 'bagging_freq': 6, 'colsample_bytree': 0.7187743617504782, 'feature_fraction': 0.8822412268247286, 'max_depth': 10, 'min_data_in_leaf': 42, 'num_leaves': 279, 'reg_lambda': 114.8060332041216, 'subsample': 0.8631504025541011}.
# [I 2019-11-24 13:42:33,237] Setting status of trial#571 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 13:45:19,125] Setting status of trial#572 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 13:46:12,993] Setting status of trial#573 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 14:05:22,958] Finished trial#574 resulted in value: 1.138207329267806. Current best value is 1.1378522421159347 with parameters: {'bagging_fraction': 0.42523401307460185, 'bagging_freq': 6, 'colsample_bytree': 0.7187743617504782, 'feature_fraction': 0.8822412268247286, 'max_depth': 10, 'min_data_in_leaf': 42, 'num_leaves': 279, 'reg_lambda': 114.8060332041216, 'subsample': 0.8631504025541011}.
# [I 2019-11-24 14:06:16,000] Setting status of trial#575 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 14:09:19,570] Setting status of trial#576 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 14:19:25,271] Setting status of trial#577 as TrialState.PRUNED. Trial was pruned at iteration 800.
# [I 2019-11-24 14:22:16,255] Setting status of trial#578 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 14:23:08,231] Setting status of trial#579 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 14:26:18,137] Setting status of trial#580 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 14:29:16,484] Setting status of trial#581 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-11-24 14:30:11,867] Setting status of trial#582 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 14:31:07,753] Setting status of trial#583 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 14:32:03,080] Setting status of trial#584 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-11-24 14:41:55,690] Setting status of trial#585 as TrialState.PRUNED. Trial was pruned at iteration 800.
