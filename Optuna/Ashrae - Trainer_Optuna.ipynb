# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
from catboost import CatBoostRegressor, Pool
import random
import gc
import os
import datetime
import pickle
import optuna
import sqlite3

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_squared_error

myfavouritenumber = 0
seed = myfavouritenumber
random.seed(seed)

pd.set_option('max_rows', 9999)
pd.set_option('max_columns', 9999)

# %% [markdown]
# Half_Half_LightGBM Training

# %%
class Trainer:
    def __init__(self, importance_df, model_type='lgb', use_feature_num=None):
        self.model_type = model_type
        
        if use_feature_num is not None:
            self.features = importance_df['feature'][:use_feature_num].tolist()
        else:
            self.features = None
            
    def train_half_optuna(self, X_train, y_train, params, num_boost_round, early_stopping_rounds, verbose=200, trial=None):
        
        if self.features is None:
            self.features = X_train.columns
            
        self.features = [c for c in self.features if c not in ['M']]
            
        self.X_train = X_train[self.features]
        self.y_train = y_train
        pruning_callback = optuna.integration.LightGBMPruningCallback(trial, 'rmse')
        
        if self.model_type == 'lgb':
            d_half_1 = lgb.Dataset(self.X_train[:int(self.X_train.shape[0] / 2)], 
                                   label=self.y_train[:int(X_train.shape[0] / 2)])
            d_half_2 = lgb.Dataset(self.X_train[int(self.X_train.shape[0] / 2):], 
                                   label=self.y_train[int(X_train.shape[0] / 2):])

            self.model_1 = lgb.train(params, train_set=d_half_1, num_boost_round=num_boost_round, 
                                     valid_sets=[d_half_2], verbose_eval=verbose, 
                                     early_stopping_rounds=early_stopping_rounds, 
                                     callbacks=[pruning_callback])
            
            oof = self.model_1.predict(self.X_train[int(self.X_train.shape[0] / 2):],
                                       num_iteration=self.model_1.best_iteration)
            oof = np.clip(oof, 0, a_max=None)
            
            rmse = np.sqrt(mean_squared_error(self.y_train[int(X_train.shape[0] / 2):], oof))
            
        return rmse

# %%
# config
train_pkl_path = '../input/prep_train_20191202_list.pkl'
importance_path = '../Importance/importance_20191202.csv'
model_type = 'lgb'

# Create SQLite Table
con = sqlite3.connect('ashrae_lgb_3.db')

def objective(trial):
    # Search Parameter Range
    set_lgb_params = {
        'objective': 'regression',
        'boosting_type': 'goss',
        'metric': 'rmse',
        'n_jobs': -1,
        'learning_rate': 0.01,
        'max_bin': 255,
        'max_depth': trial.suggest_int('max_depth', 10, 20),
        'num_leaves': trial.suggest_int('num_leaves', 100, 300),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 0.9),
        'subsample': trial.suggest_uniform('subsample', 0.6, 0.9),
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 10, 50),
        'feature_fraction': trial.suggest_uniform('feature_fraction', 0.3, 0.9),
        'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-2, 1e+3),
        'verbose': -1,
        'seed': 42
    }
    
    num_boost_round = 5000
    early_stopping_rounds = 200
    num_feature = 40
    verbose = False
    
    # Train Model
    trainer = Trainer(importance_df=importance_df, model_type=model_type, use_feature_num=num_feature)
    rmse = trainer.train_half_optuna(train[0], train[1], set_lgb_params, num_boost_round, 
                                       early_stopping_rounds, verbose, trial)

    return rmse

# %%
# Training
# Data Loading
with open(train_pkl_path, 'rb') as f:
    train = pickle.load(f)

importance_df = pd.read_csv(importance_path)

pruner = optuna.pruners.SuccessiveHalvingPruner(min_resource=50)

# New Study
study = optuna.create_study(
    study_name='ashrae_lgb_3',
    storage='sqlite:///ashrae_lgb_3.db',
    load_if_exists=True,
    direction='minimize',
    pruner=pruner
)

# Reload Intermediate state
# study = optuna.load_study(
#     study_name='ashrae_lgb',
#     storage='sqlite:///ashrae_lgb.db',
#     pruner=pruner
# )

study.optimize(objective, timeout=60*60*48)
# Out:
# [I 2019-12-05 07:28:24,418] Using an existing study with name 'ashrae_lgb_3' instead of creating a new one.
# [I 2019-12-05 07:32:52,243] Finished trial#1 resulted in value: 1.5094749968513392. Current best value is 1.5094749968513392 with parameters: {'colsample_bytree': 0.8538078457016902, 'feature_fraction': 0.6828417210061907, 'max_depth': 10, 'min_data_in_leaf': 40, 'num_leaves': 275, 'reg_lambda': 108.33570081783267, 'subsample': 0.8186750756290126}.
# [I 2019-12-05 07:37:26,371] Finished trial#2 resulted in value: 1.468674766541497. Current best value is 1.468674766541497 with parameters: {'colsample_bytree': 0.7480508566998729, 'feature_fraction': 0.8152382909987603, 'max_depth': 14, 'min_data_in_leaf': 45, 'num_leaves': 132, 'reg_lambda': 110.29781842683936, 'subsample': 0.8773961653276434}.
# [I 2019-12-05 07:38:33,075] Setting status of trial#3 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 07:42:27,094] Setting status of trial#4 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 07:43:27,904] Setting status of trial#5 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 07:49:32,371] Finished trial#6 resulted in value: 1.3861827447103088. Current best value is 1.3861827447103088 with parameters: {'colsample_bytree': 0.6375046050430762, 'feature_fraction': 0.879824646708159, 'max_depth': 18, 'min_data_in_leaf': 15, 'num_leaves': 255, 'reg_lambda': 39.96758320448672, 'subsample': 0.7601263321749685}.
# [I 2019-12-05 07:50:32,232] Setting status of trial#7 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 07:51:42,217] Setting status of trial#8 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 07:52:56,306] Setting status of trial#9 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 07:54:06,282] Setting status of trial#10 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 07:59:46,365] Finished trial#11 resulted in value: 1.3949841636897504. Current best value is 1.3861827447103088 with parameters: {'colsample_bytree': 0.6375046050430762, 'feature_fraction': 0.879824646708159, 'max_depth': 18, 'min_data_in_leaf': 15, 'num_leaves': 255, 'reg_lambda': 39.96758320448672, 'subsample': 0.7601263321749685}.
# [I 2019-12-05 08:03:36,512] Setting status of trial#12 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 08:07:46,362] Setting status of trial#13 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 08:09:18,880] Setting status of trial#14 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 08:10:50,547] Setting status of trial#15 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 08:16:54,505] Finished trial#16 resulted in value: 1.3846552760882818. Current best value is 1.3846552760882818 with parameters: {'colsample_bytree': 0.6446820363068849, 'feature_fraction': 0.8995423930082788, 'max_depth': 20, 'min_data_in_leaf': 11, 'num_leaves': 257, 'reg_lambda': 866.825333775333, 'subsample': 0.663255757899185}.
# [I 2019-12-05 08:18:32,771] Setting status of trial#17 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 08:22:34,051] Setting status of trial#18 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 08:23:36,129] Setting status of trial#19 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 08:25:10,036] Setting status of trial#20 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 08:29:11,832] Setting status of trial#21 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 08:30:45,160] Setting status of trial#22 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 08:34:45,949] Setting status of trial#23 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 08:36:19,739] Setting status of trial#24 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 08:37:55,513] Setting status of trial#25 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 08:39:37,877] Setting status of trial#26 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 08:41:13,769] Setting status of trial#27 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 08:42:42,922] Setting status of trial#28 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 08:44:15,715] Setting status of trial#29 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 08:45:34,965] Setting status of trial#30 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 08:47:12,407] Setting status of trial#31 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 08:48:32,814] Setting status of trial#32 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 08:49:49,350] Setting status of trial#33 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 08:51:07,699] Setting status of trial#34 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 08:52:35,460] Setting status of trial#35 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 08:53:46,739] Setting status of trial#36 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 08:55:17,844] Setting status of trial#37 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 08:56:22,514] Setting status of trial#38 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 08:57:45,144] Setting status of trial#39 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 08:58:56,740] Setting status of trial#40 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 09:00:27,700] Setting status of trial#41 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 09:01:39,064] Setting status of trial#42 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 09:02:47,176] Setting status of trial#43 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 09:04:11,725] Setting status of trial#44 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 09:05:18,695] Setting status of trial#45 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 09:06:39,021] Setting status of trial#46 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 09:08:00,299] Setting status of trial#47 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 09:09:32,500] Setting status of trial#48 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 09:13:40,323] Setting status of trial#49 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 09:14:41,052] Setting status of trial#50 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 09:16:11,784] Setting status of trial#51 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 09:21:57,627] Finished trial#52 resulted in value: 1.3929698874486531. Current best value is 1.3846552760882818 with parameters: {'colsample_bytree': 0.6446820363068849, 'feature_fraction': 0.8995423930082788, 'max_depth': 20, 'min_data_in_leaf': 11, 'num_leaves': 257, 'reg_lambda': 866.825333775333, 'subsample': 0.663255757899185}.
# [I 2019-12-05 09:25:42,161] Setting status of trial#53 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 09:27:14,256] Setting status of trial#54 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 09:33:05,289] Finished trial#55 resulted in value: 1.3904362264108874. Current best value is 1.3846552760882818 with parameters: {'colsample_bytree': 0.6446820363068849, 'feature_fraction': 0.8995423930082788, 'max_depth': 20, 'min_data_in_leaf': 11, 'num_leaves': 257, 'reg_lambda': 866.825333775333, 'subsample': 0.663255757899185}.
# [I 2019-12-05 09:38:48,862] Finished trial#56 resulted in value: 1.3914035038283732. Current best value is 1.3846552760882818 with parameters: {'colsample_bytree': 0.6446820363068849, 'feature_fraction': 0.8995423930082788, 'max_depth': 20, 'min_data_in_leaf': 11, 'num_leaves': 257, 'reg_lambda': 866.825333775333, 'subsample': 0.663255757899185}.
# [I 2019-12-05 09:42:38,436] Setting status of trial#57 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 09:44:11,811] Setting status of trial#58 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 09:48:10,697] Setting status of trial#59 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 09:51:54,039] Setting status of trial#60 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 09:57:39,046] Finished trial#61 resulted in value: 1.3880935867756143. Current best value is 1.3846552760882818 with parameters: {'colsample_bytree': 0.6446820363068849, 'feature_fraction': 0.8995423930082788, 'max_depth': 20, 'min_data_in_leaf': 11, 'num_leaves': 257, 'reg_lambda': 866.825333775333, 'subsample': 0.663255757899185}.
# [I 2019-12-05 10:03:48,539] Finished trial#62 resulted in value: 1.3900799823011418. Current best value is 1.3846552760882818 with parameters: {'colsample_bytree': 0.6446820363068849, 'feature_fraction': 0.8995423930082788, 'max_depth': 20, 'min_data_in_leaf': 11, 'num_leaves': 257, 'reg_lambda': 866.825333775333, 'subsample': 0.663255757899185}.
# [I 2019-12-05 10:09:25,793] Finished trial#63 resulted in value: 1.3862270951235909. Current best value is 1.3846552760882818 with parameters: {'colsample_bytree': 0.6446820363068849, 'feature_fraction': 0.8995423930082788, 'max_depth': 20, 'min_data_in_leaf': 11, 'num_leaves': 257, 'reg_lambda': 866.825333775333, 'subsample': 0.663255757899185}.
# [I 2019-12-05 10:10:57,680] Setting status of trial#64 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 10:15:01,935] Setting status of trial#65 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 10:19:13,268] Setting status of trial#66 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 10:20:45,398] Setting status of trial#67 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 10:22:18,960] Setting status of trial#68 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 10:26:23,031] Setting status of trial#69 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 10:30:23,331] Setting status of trial#70 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 10:34:18,012] Setting status of trial#71 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 10:35:52,338] Setting status of trial#72 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 10:37:26,638] Setting status of trial#73 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 10:39:00,156] Setting status of trial#74 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 10:43:04,290] Setting status of trial#75 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 10:44:37,553] Setting status of trial#76 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 10:46:10,303] Setting status of trial#77 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 10:47:42,840] Setting status of trial#78 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 10:51:48,629] Setting status of trial#79 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 10:53:24,698] Setting status of trial#80 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 10:54:57,335] Setting status of trial#81 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 10:56:32,054] Setting status of trial#82 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 11:00:30,516] Setting status of trial#83 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 11:02:06,259] Setting status of trial#84 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 11:03:46,168] Setting status of trial#85 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 11:05:19,235] Setting status of trial#86 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 11:06:56,618] Setting status of trial#87 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 11:08:33,106] Setting status of trial#88 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 11:10:07,832] Setting status of trial#89 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 11:14:10,899] Setting status of trial#90 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 11:18:14,668] Setting status of trial#91 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 11:19:52,137] Setting status of trial#92 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 11:21:25,559] Setting status of trial#93 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 11:22:51,608] Setting status of trial#94 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 11:24:17,920] Setting status of trial#95 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 11:30:22,037] Finished trial#96 resulted in value: 1.376104658769496. Current best value is 1.376104658769496 with parameters: {'colsample_bytree': 0.6590413006581874, 'feature_fraction': 0.8538647276906907, 'max_depth': 20, 'min_data_in_leaf': 29, 'num_leaves': 280, 'reg_lambda': 78.44102519695186, 'subsample': 0.6090180900285186}.
# [I 2019-12-05 11:34:32,867] Setting status of trial#97 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 11:38:51,577] Setting status of trial#98 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 11:42:56,359] Setting status of trial#99 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 11:47:00,907] Setting status of trial#100 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 11:51:06,387] Setting status of trial#101 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 11:55:00,084] Setting status of trial#102 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 11:56:33,239] Setting status of trial#103 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 12:00:39,746] Setting status of trial#104 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 12:04:38,637] Setting status of trial#105 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 12:06:09,842] Setting status of trial#106 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 12:07:41,555] Setting status of trial#107 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 12:08:55,392] Setting status of trial#108 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 12:10:23,780] Setting status of trial#109 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 12:16:14,484] Finished trial#110 resulted in value: 1.388683386462902. Current best value is 1.376104658769496 with parameters: {'colsample_bytree': 0.6590413006581874, 'feature_fraction': 0.8538647276906907, 'max_depth': 20, 'min_data_in_leaf': 29, 'num_leaves': 280, 'reg_lambda': 78.44102519695186, 'subsample': 0.6090180900285186}.
# [I 2019-12-05 12:22:07,734] Finished trial#111 resulted in value: 1.3889709602122695. Current best value is 1.376104658769496 with parameters: {'colsample_bytree': 0.6590413006581874, 'feature_fraction': 0.8538647276906907, 'max_depth': 20, 'min_data_in_leaf': 29, 'num_leaves': 280, 'reg_lambda': 78.44102519695186, 'subsample': 0.6090180900285186}.
# [I 2019-12-05 12:23:39,019] Setting status of trial#112 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 12:25:16,399] Setting status of trial#113 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 12:29:18,881] Setting status of trial#114 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 12:33:16,735] Setting status of trial#115 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 12:37:19,811] Setting status of trial#116 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 12:41:29,993] Setting status of trial#117 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 12:43:05,912] Setting status of trial#118 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 12:44:41,095] Setting status of trial#119 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 12:46:18,923] Setting status of trial#120 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 12:50:30,257] Setting status of trial#121 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 12:54:41,997] Setting status of trial#122 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 12:56:18,094] Setting status of trial#123 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 12:57:51,443] Setting status of trial#124 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 12:59:27,207] Setting status of trial#125 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 13:01:00,380] Setting status of trial#126 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 13:02:27,699] Setting status of trial#127 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 13:03:59,348] Setting status of trial#128 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 13:05:34,715] Setting status of trial#129 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 13:11:30,751] Finished trial#130 resulted in value: 1.3717736881052378. Current best value is 1.3717736881052378 with parameters: {'colsample_bytree': 0.7007960428402581, 'feature_fraction': 0.899332875974873, 'max_depth': 20, 'min_data_in_leaf': 20, 'num_leaves': 277, 'reg_lambda': 237.25731546690733, 'subsample': 0.8703772224618189}.
# [I 2019-12-05 13:15:45,245] Setting status of trial#131 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 13:20:00,199] Setting status of trial#132 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 13:24:00,862] Setting status of trial#133 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 13:28:04,241] Setting status of trial#134 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 13:32:11,593] Setting status of trial#135 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 13:33:39,012] Setting status of trial#136 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 13:35:00,196] Setting status of trial#137 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 13:39:05,544] Setting status of trial#138 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 13:43:15,484] Setting status of trial#139 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 13:47:27,249] Setting status of trial#140 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 13:48:59,358] Setting status of trial#141 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 13:50:14,363] Setting status of trial#142 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 13:51:33,513] Setting status of trial#143 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 13:52:38,337] Setting status of trial#144 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 13:54:15,809] Setting status of trial#145 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 13:55:50,157] Setting status of trial#146 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 13:57:25,820] Setting status of trial#147 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 13:59:01,824] Setting status of trial#148 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 14:00:14,055] Setting status of trial#149 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 14:04:17,753] Setting status of trial#150 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 14:10:13,088] Finished trial#151 resulted in value: 1.3944898829299228. Current best value is 1.3717736881052378 with parameters: {'colsample_bytree': 0.7007960428402581, 'feature_fraction': 0.899332875974873, 'max_depth': 20, 'min_data_in_leaf': 20, 'num_leaves': 277, 'reg_lambda': 237.25731546690733, 'subsample': 0.8703772224618189}.
# [I 2019-12-05 14:14:09,049] Setting status of trial#152 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 14:15:48,463] Setting status of trial#153 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 14:17:23,844] Setting status of trial#154 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 14:19:00,016] Setting status of trial#155 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 14:20:14,136] Setting status of trial#156 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 14:26:36,617] Finished trial#157 resulted in value: 1.3702855248471535. Current best value is 1.3702855248471535 with parameters: {'colsample_bytree': 0.6942838936080526, 'feature_fraction': 0.8989966937060903, 'max_depth': 20, 'min_data_in_leaf': 36, 'num_leaves': 275, 'reg_lambda': 0.31129758193713547, 'subsample': 0.6958677000718564}.
# [I 2019-12-05 14:30:58,924] Setting status of trial#158 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 14:35:08,495] Setting status of trial#159 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 14:39:14,803] Setting status of trial#160 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 14:43:23,367] Setting status of trial#161 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 14:49:23,634] Finished trial#162 resulted in value: 1.376897744608904. Current best value is 1.3702855248471535 with parameters: {'colsample_bytree': 0.6942838936080526, 'feature_fraction': 0.8989966937060903, 'max_depth': 20, 'min_data_in_leaf': 36, 'num_leaves': 275, 'reg_lambda': 0.31129758193713547, 'subsample': 0.6958677000718564}.
# [I 2019-12-05 14:55:23,586] Finished trial#163 resulted in value: 1.3780009300699758. Current best value is 1.3702855248471535 with parameters: {'colsample_bytree': 0.6942838936080526, 'feature_fraction': 0.8989966937060903, 'max_depth': 20, 'min_data_in_leaf': 36, 'num_leaves': 275, 'reg_lambda': 0.31129758193713547, 'subsample': 0.6958677000718564}.
# [I 2019-12-05 15:01:51,002] Finished trial#164 resulted in value: 1.3712828101328522. Current best value is 1.3702855248471535 with parameters: {'colsample_bytree': 0.6942838936080526, 'feature_fraction': 0.8989966937060903, 'max_depth': 20, 'min_data_in_leaf': 36, 'num_leaves': 275, 'reg_lambda': 0.31129758193713547, 'subsample': 0.6958677000718564}.
# [I 2019-12-05 15:06:11,605] Setting status of trial#165 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 15:10:26,729] Setting status of trial#166 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 15:14:41,725] Setting status of trial#167 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 15:19:01,477] Setting status of trial#168 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 15:23:07,025] Setting status of trial#169 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 15:27:18,160] Setting status of trial#170 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 15:31:28,521] Setting status of trial#171 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 15:33:06,567] Setting status of trial#172 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 15:37:24,745] Setting status of trial#173 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 15:39:01,456] Setting status of trial#174 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 15:43:14,782] Setting status of trial#175 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 15:47:34,543] Setting status of trial#176 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 15:49:09,799] Setting status of trial#177 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 15:53:10,652] Setting status of trial#178 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 15:54:49,092] Setting status of trial#179 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 16:01:05,993] Finished trial#180 resulted in value: 1.3745741661542878. Current best value is 1.3702855248471535 with parameters: {'colsample_bytree': 0.6942838936080526, 'feature_fraction': 0.8989966937060903, 'max_depth': 20, 'min_data_in_leaf': 36, 'num_leaves': 275, 'reg_lambda': 0.31129758193713547, 'subsample': 0.6958677000718564}.
# [I 2019-12-05 16:05:15,993] Setting status of trial#181 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 16:09:26,109] Setting status of trial#182 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 16:13:31,217] Setting status of trial#183 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 16:17:39,402] Setting status of trial#184 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 16:21:56,702] Setting status of trial#185 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 16:23:32,905] Setting status of trial#186 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 16:29:27,193] Finished trial#187 resulted in value: 1.3775872683345485. Current best value is 1.3702855248471535 with parameters: {'colsample_bytree': 0.6942838936080526, 'feature_fraction': 0.8989966937060903, 'max_depth': 20, 'min_data_in_leaf': 36, 'num_leaves': 275, 'reg_lambda': 0.31129758193713547, 'subsample': 0.6958677000718564}.
# [I 2019-12-05 16:33:28,824] Setting status of trial#188 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 16:39:44,913] Finished trial#189 resulted in value: 1.37859670616471. Current best value is 1.3702855248471535 with parameters: {'colsample_bytree': 0.6942838936080526, 'feature_fraction': 0.8989966937060903, 'max_depth': 20, 'min_data_in_leaf': 36, 'num_leaves': 275, 'reg_lambda': 0.31129758193713547, 'subsample': 0.6958677000718564}.
# [I 2019-12-05 16:43:51,828] Setting status of trial#190 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 16:48:06,796] Setting status of trial#191 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 16:52:13,822] Setting status of trial#192 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 16:56:23,232] Setting status of trial#193 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 17:00:38,968] Setting status of trial#194 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 17:02:19,816] Setting status of trial#195 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 17:08:18,219] Finished trial#196 resulted in value: 1.3794483403123683. Current best value is 1.3702855248471535 with parameters: {'colsample_bytree': 0.6942838936080526, 'feature_fraction': 0.8989966937060903, 'max_depth': 20, 'min_data_in_leaf': 36, 'num_leaves': 275, 'reg_lambda': 0.31129758193713547, 'subsample': 0.6958677000718564}.
# [I 2019-12-05 17:12:36,531] Setting status of trial#197 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 17:18:48,756] Finished trial#198 resulted in value: 1.3769865101293661. Current best value is 1.3702855248471535 with parameters: {'colsample_bytree': 0.6942838936080526, 'feature_fraction': 0.8989966937060903, 'max_depth': 20, 'min_data_in_leaf': 36, 'num_leaves': 275, 'reg_lambda': 0.31129758193713547, 'subsample': 0.6958677000718564}.
# [I 2019-12-05 17:22:56,987] Setting status of trial#199 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 17:26:58,684] Setting status of trial#200 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 17:31:03,580] Setting status of trial#201 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 17:35:21,626] Setting status of trial#202 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 17:39:27,553] Setting status of trial#203 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 17:45:37,831] Finished trial#204 resulted in value: 1.3761399210624952. Current best value is 1.3702855248471535 with parameters: {'colsample_bytree': 0.6942838936080526, 'feature_fraction': 0.8989966937060903, 'max_depth': 20, 'min_data_in_leaf': 36, 'num_leaves': 275, 'reg_lambda': 0.31129758193713547, 'subsample': 0.6958677000718564}.
# [I 2019-12-05 17:49:45,537] Setting status of trial#205 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 17:55:41,924] Finished trial#206 resulted in value: 1.3789949168825961. Current best value is 1.3702855248471535 with parameters: {'colsample_bytree': 0.6942838936080526, 'feature_fraction': 0.8989966937060903, 'max_depth': 20, 'min_data_in_leaf': 36, 'num_leaves': 275, 'reg_lambda': 0.31129758193713547, 'subsample': 0.6958677000718564}.
# [I 2019-12-05 17:57:20,510] Setting status of trial#207 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 18:03:34,988] Finished trial#208 resulted in value: 1.3792751531939478. Current best value is 1.3702855248471535 with parameters: {'colsample_bytree': 0.6942838936080526, 'feature_fraction': 0.8989966937060903, 'max_depth': 20, 'min_data_in_leaf': 36, 'num_leaves': 275, 'reg_lambda': 0.31129758193713547, 'subsample': 0.6958677000718564}.
# [I 2019-12-05 18:09:44,584] Finished trial#209 resulted in value: 1.3751788666187164. Current best value is 1.3702855248471535 with parameters: {'colsample_bytree': 0.6942838936080526, 'feature_fraction': 0.8989966937060903, 'max_depth': 20, 'min_data_in_leaf': 36, 'num_leaves': 275, 'reg_lambda': 0.31129758193713547, 'subsample': 0.6958677000718564}.
# [I 2019-12-05 18:13:45,234] Setting status of trial#210 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 18:15:23,912] Setting status of trial#211 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 18:19:32,234] Setting status of trial#212 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 18:25:24,153] Finished trial#213 resulted in value: 1.3746344370595613. Current best value is 1.3702855248471535 with parameters: {'colsample_bytree': 0.6942838936080526, 'feature_fraction': 0.8989966937060903, 'max_depth': 20, 'min_data_in_leaf': 36, 'num_leaves': 275, 'reg_lambda': 0.31129758193713547, 'subsample': 0.6958677000718564}.
# [I 2019-12-05 18:31:25,664] Finished trial#214 resulted in value: 1.377737539435851. Current best value is 1.3702855248471535 with parameters: {'colsample_bytree': 0.6942838936080526, 'feature_fraction': 0.8989966937060903, 'max_depth': 20, 'min_data_in_leaf': 36, 'num_leaves': 275, 'reg_lambda': 0.31129758193713547, 'subsample': 0.6958677000718564}.
# [I 2019-12-05 18:37:17,480] Finished trial#215 resulted in value: 1.3773891500927562. Current best value is 1.3702855248471535 with parameters: {'colsample_bytree': 0.6942838936080526, 'feature_fraction': 0.8989966937060903, 'max_depth': 20, 'min_data_in_leaf': 36, 'num_leaves': 275, 'reg_lambda': 0.31129758193713547, 'subsample': 0.6958677000718564}.
# [I 2019-12-05 18:41:28,099] Setting status of trial#216 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 18:47:40,804] Finished trial#217 resulted in value: 1.3710459923977658. Current best value is 1.3702855248471535 with parameters: {'colsample_bytree': 0.6942838936080526, 'feature_fraction': 0.8989966937060903, 'max_depth': 20, 'min_data_in_leaf': 36, 'num_leaves': 275, 'reg_lambda': 0.31129758193713547, 'subsample': 0.6958677000718564}.
# [I 2019-12-05 18:51:50,152] Setting status of trial#218 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 18:55:55,572] Setting status of trial#219 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 19:02:02,455] Finished trial#220 resulted in value: 1.3771169207457548. Current best value is 1.3702855248471535 with parameters: {'colsample_bytree': 0.6942838936080526, 'feature_fraction': 0.8989966937060903, 'max_depth': 20, 'min_data_in_leaf': 36, 'num_leaves': 275, 'reg_lambda': 0.31129758193713547, 'subsample': 0.6958677000718564}.
# [I 2019-12-05 19:06:07,122] Setting status of trial#221 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 19:10:12,886] Setting status of trial#222 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 19:14:28,872] Setting status of trial#223 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 19:18:38,309] Setting status of trial#224 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 19:24:42,993] Finished trial#225 resulted in value: 1.371409995173505. Current best value is 1.3702855248471535 with parameters: {'colsample_bytree': 0.6942838936080526, 'feature_fraction': 0.8989966937060903, 'max_depth': 20, 'min_data_in_leaf': 36, 'num_leaves': 275, 'reg_lambda': 0.31129758193713547, 'subsample': 0.6958677000718564}.
# [I 2019-12-05 19:28:51,909] Setting status of trial#226 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 19:32:58,265] Setting status of trial#227 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 19:34:39,089] Setting status of trial#228 as TrialState.PRUNED. Trial was pruned at iteration 50.
# [I 2019-12-05 19:38:48,529] Setting status of trial#229 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 19:45:06,569] Finished trial#230 resulted in value: 1.371459550150482. Current best value is 1.3702855248471535 with parameters: {'colsample_bytree': 0.6942838936080526, 'feature_fraction': 0.8989966937060903, 'max_depth': 20, 'min_data_in_leaf': 36, 'num_leaves': 275, 'reg_lambda': 0.31129758193713547, 'subsample': 0.6958677000718564}.
# [I 2019-12-05 19:49:15,122] Setting status of trial#231 as TrialState.PRUNED. Trial was pruned at iteration 200.
# [I 2019-12-05 19:55:33,679] Finished trial#232 resulted in value: 1.3705084766595574. Current best value is 1.3702855248471535 with parameters: {'colsample_bytree': 0.6942838936080526, 'feature_fraction': 0.8989966937060903, 'max_depth': 20, 'min_data_in_leaf': 36, 'num_leaves': 275, 'reg_lambda': 0.31129758193713547, 'subsample': 0.6958677000718564}.
# [I 2019-12-05 20:01:48,724] Finished trial#233 resulted in value: 1.3680225657560139. Current best value is 1.3680225657560139 with parameters: {'colsample_bytree': 0.6290250220421024, 'feature_fraction': 0.8782970255105117, 'max_depth': 20, 'min_data_in_leaf': 14, 'num_leaves': 300, 'reg_lambda': 163.6394461120956, 'subsample': 0.6549764150917482}.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-3c1152c5e5f8> in <module>
#      24 # )
#      25
# ---> 26 study.optimize(objective, timeout=60*60*48)
#
# d:\python\kaggle\ashrae~1\venv~1\lib\site-packages\optuna\study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial)
#     259             if n_jobs == 1:
#     260                 self._optimize_sequential(func, n_trials, timeout, catch, callbacks,
# --> 261                                           gc_after_trial)
#     262             else:
#     263                 self._optimize_parallel(func, n_trials, timeout, n_jobs, catch, callbacks,
#
# d:\python\kaggle\ashrae~1\venv~1\lib\site-packages\optuna\study.py in _optimize_sequential(self, func, n_trials, timeout, catch, callbacks, gc_after_trial)
#     441                     break
#     442
# --> 443             self._run_trial_and_callbacks(func, catch, callbacks, gc_after_trial)
#     444
#     445     def _optimize_parallel(
#
# d:\python\kaggle\ashrae~1\venv~1\lib\site-packages\optuna\study.py in _run_trial_and_callbacks(self, func, catch, callbacks, gc_after_trial)
#     518         # type: (...) -> None
#     519
# --> 520         trial = self._run_trial(func, catch, gc_after_trial)
#     521         if callbacks is not None:
#     522             frozen_trial = self._storage.get_trial(trial._trial_id)
#
# d:\python\kaggle\ashrae~1\venv~1\lib\site-packages\optuna\study.py in _run_trial(self, func, catch, gc_after_trial)
#     537
#     538         try:
# --> 539             result = func(trial)
#     540         except exceptions.TrialPruned as e:
#     541             message = 'Setting status of trial#{} as {}. {}'.format(trial_number,
#
# <ipython-input-7-eb89e0e7cd42> in objective(trial)
#      35     trainer = Trainer(importance_df=importance_df, model_type=model_type, use_feature_num=num_feature)
#      36     rmse = trainer.train_half_optuna(train[0], train[1], set_lgb_params, num_boost_round,
# ---> 37                                        early_stopping_rounds, verbose, trial)
#      38
#      39     return rmse
#
# <ipython-input-2-e972ed8552a7> in train_half_optuna(self, X_train, y_train, params, num_boost_round, early_stopping_rounds, verbose, trial)
#      28                                      valid_sets=[d_half_2], verbose_eval=verbose,
#      29                                      early_stopping_rounds=early_stopping_rounds,
# ---> 30                                      callbacks=[pruning_callback])
#      31
#      32             oof = self.model_1.predict(self.X_train[int(self.X_train.shape[0] / 2):],
#
# d:\python\kaggle\ashrae~1\venv~1\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     247                                     evaluation_result_list=None))
#     248
# --> 249         booster.update(fobj=fobj)
#     250
#     251         evaluation_result_list = []
#
# d:\python\kaggle\ashrae~1\venv~1\lib\site-packages\lightgbm\basic.py in update(self, train_set, fobj)
#    1924             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    1925                 self.handle,
# -> 1926                 ctypes.byref(is_finished)))
#    1927             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    1928             return is_finished.value == 1
#
# KeyboardInterrupt:
